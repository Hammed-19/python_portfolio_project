# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('ipl_data.csv')

# %%
df.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2    2017       Pune  06-04-2017               Mumbai Indians
# 2   3    2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4    2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5    2017  Bangalore  08-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
df.shape
# Out:
# (756, 18)

# %%
column_names = df.columns
column_names
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
df['team1'].unique()
# Out:
# array(['Sunrisers Hyderabad', 'Mumbai Indians', 'Gujarat Lions',
#        'Rising Pune Supergiant', 'Royal Challengers Bangalore',
#        'Kolkata Knight Riders', 'Delhi Daredevils', 'Kings XI Punjab',
#        'Chennai Super Kings', 'Rajasthan Royals', 'Deccan Chargers',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Rising Pune Supergiants',
#        'Delhi Capitals'], dtype=object)

# %%
# max matches played in a city

matches_per_city = df['city'].value_counts()[0:5]
matches_per_city
# Out:
# Mumbai       101
# Kolkata       77
# Delhi         74
# Bangalore     66
# Hyderabad     64
# Name: city, dtype: int64

# %%
#plotting a bar chart for top 5 cities to host a match
plt.figure(figsize=(5,5))
plt.bar(list(df['city'].value_counts()[0:5].keys()),list(df['city'].value_counts()[0:5]))
plt.show()

# %%
plt.pie(matches_per_city, labels=matches_per_city.index, autopct='%1.1f%%', )
plt.title('Distribution of Matches Hosted in Each City')
plt.show()

# %%
all_teams = pd.concat([df['team1'], df['team2']])

matches_per_team = all_teams.value_counts()

matches_per_team
# Out:
# Mumbai Indians                 187
# Royal Challengers Bangalore    180
# Kolkata Knight Riders          178
# Kings XI Punjab                176
# Chennai Super Kings            164
# Delhi Daredevils               161
# Rajasthan Royals               147
# Sunrisers Hyderabad            108
# Deccan Chargers                 75
# Pune Warriors                   46
# Gujarat Lions                   30
# Rising Pune Supergiant          16
# Delhi Capitals                  16
# Kochi Tuskers Kerala            14
# Rising Pune Supergiants         14
# dtype: int64

# %%
top_5_teams = matches_per_team.head(5)
top_5_teams
# Out:
# Mumbai Indians                 187
# Royal Challengers Bangalore    180
# Kolkata Knight Riders          178
# Kings XI Punjab                176
# Chennai Super Kings            164
# dtype: int64

# %%
# Plotting the horizontal bar chart
plt.barh(top_5_teams.index, top_5_teams.values, color='green')
plt.title('Top 5 Teams by Number of Matches Played')
plt.xlabel('Number of Matches Played')
plt.ylabel('Team')
plt.show()

# %%
#top 10 players with most MOTM award

top_10_players = df['player_of_match'].value_counts()[0:10]
top_10_players
# Out:
# CH Gayle          21
# AB de Villiers    20
# RG Sharma         17
# MS Dhoni          17
# DA Warner         17
# YK Pathan         16
# SR Watson         15
# SK Raina          14
# G Gambhir         13
# MEK Hussey        12
# Name: player_of_match, dtype: int64

# %%
# Plotting the histogram
plt.bar(top_10_players.index, top_10_players.values, color='lightblue')
plt.title('Top 10 Players with Most "Player of the Match" Awards')
plt.xlabel('Player')
plt.ylabel('Number of Awards')
plt.xticks(rotation=45, ha='right')

# %%
# Plotting the pie chart
plt.pie(top_10_players, labels=top_10_players.index, autopct='%1.1f%%', startangle=90, colors=plt.cm.Paired.colors)
plt.title('Distribution of "Player of the Match" Awards Among Top 10 Players')
plt.show()

# %%
#Extracting the records where a team won batting first
batting_first=df[df['win_by_runs']!=0]
batting_first
# Out:
#         id  season       city        date                        team1  \
# 0        1    2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 4        5    2017  Bangalore  08-04-2017  Royal Challengers Bangalore
# 8        9    2017       Pune  11-04-2017             Delhi Daredevils
# 13      14    2017    Kolkata  15-04-2017        Kolkata Knight Riders
# 14      15    2017      Delhi  15-04-2017             Delhi Daredevils
# ..     ...     ...        ...         ...                          ...
# 741  11337    2019      Delhi  28-04-2019               Delhi Capitals
# 742  11338    2019    Kolkata  28-04-2019        Kolkata Knight Riders
# 743  11339    2019  Hyderabad  29-04-2019          Sunrisers Hyderabad
# 745  11341    2019    Chennai  01-05-2019          Chennai Super Kings
# 755  11415    2019  Hyderabad  12-05-2019               Mumbai Indians
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
batting_first['winner'].value_counts()
# Out:
# Mumbai Indians                 57
# Chennai Super Kings            52
# Kings XI Punjab                38
# Kolkata Knight Riders          36
# Royal Challengers Bangalore    35
# Sunrisers Hyderabad            30
# Rajasthan Royals               27
# Delhi Daredevils               25
# Deccan Chargers                18
# Pune Warriors                   6
# Rising Pune Supergiant          5
# Delhi Capitals                  3
# Kochi Tuskers Kerala            2
# Rising Pune Supergiants         2
# Gujarat Lions                   1
# Name: winner, dtype: int64

# %%
#Making a bar-plot for top 5 teams with most wins after batting first
plt.figure(figsize=(7,7))
plt.xticks(rotation=40, ha='right')

plt.bar(list(batting_first['winner'].value_counts()[0:5].keys()),list(batting_first['winner'].value_counts()[0:5]),color=["blue","yellow","orange","violet","maroon"])
plt.show()

# %%
#Making a pie chart
plt.figure(figsize=(7,7))
plt.pie(list(batting_first['winner'].value_counts()[0:5]),labels=list(batting_first['winner'].value_counts()[0:5].keys()),autopct='%0.1f%%')
plt.show()

# %%
#extracting those records where a team has won after batting second
batting_second=df[df['win_by_wickets']!=0]
batting_second
# Out:
#         id  season           city        date                   team1  \
# 1        2    2017           Pune  06-04-2017          Mumbai Indians
# 2        3    2017         Rajkot  07-04-2017           Gujarat Lions
# 3        4    2017         Indore  08-04-2017  Rising Pune Supergiant
# 5        6    2017      Hyderabad  09-04-2017           Gujarat Lions
# 6        7    2017         Mumbai  09-04-2017   Kolkata Knight Riders
# ..     ...     ...            ...         ...                     ...
# 750  11346    2019         Mohali  05-05-2019     Chennai Super Kings
# 751  11347    2019         Mumbai  05-05-2019   Kolkata Knight Riders
# 752  11412    2019        Chennai  07-05-2019     Chennai Super Kings
# 753  11413    2019  Visakhapatnam  08-05-2019     Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam  10-05-2019          Delhi Capitals
#
#                       team2             toss_winner toss_decision  result  \
# ...

# %%
#Making a histogram for frequency of wins w.r.t number of wickets
plt.figure(figsize=(7,7))
plt.hist(batting_second['win_by_wickets'],bins=30)
plt.show()

# %%
#Finding out the frequency of number of wins w.r.t each time after batting second
batting_second['winner'].value_counts()
# Out:
# Kolkata Knight Riders          56
# Mumbai Indians                 50
# Royal Challengers Bangalore    48
# Chennai Super Kings            48
# Rajasthan Royals               46
# Kings XI Punjab                42
# Delhi Daredevils               42
# Sunrisers Hyderabad            27
# Gujarat Lions                  12
# Deccan Chargers                11
# Pune Warriors                   6
# Delhi Capitals                  6
# Rising Pune Supergiant          5
# Kochi Tuskers Kerala            4
# Rising Pune Supergiants         3
# Name: winner, dtype: int64

# %%
#Making a bar plot for top-3 teams with most wins after batting second
plt.figure(figsize=(7,7))
plt.bar(list(batting_second['winner'].value_counts()[0:3].keys()),list(batting_second['winner'].value_counts()[0:3]),color=["blue","green","orange"])
plt.show()

# %%
#Making a pie chart for distribution of most wins after batting second
plt.figure(figsize=(7,7))
plt.pie(list(batting_second['winner'].value_counts()),labels=list(batting_second['winner'].value_counts().keys()),autopct='%0.1f%%')
plt.show()

# %%
#Finding out how many times a team has won the match after winning the toss
import numpy as np
np.sum(df['toss_winner']==df['winner'])
# Out:
# 393

# %%
393/756
# Out:
# 0.5198412698412699

# %%
# this indicates that winning a toss doesn't increase your chance of winning the match by much difference
